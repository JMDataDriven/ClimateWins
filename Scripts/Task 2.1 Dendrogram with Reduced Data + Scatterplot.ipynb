# %% [markdown]
# ## Import Reduced Data Frame and Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
import operator
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from matplotlib.pyplot import figure
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster

# %%
# path variable 
path = r'C:\Users\jmiel\JENNY_STUFF\MY_DOCS\CareerFoundry\ClimateWins'

# Upload weather file
reduced = pd.read_csv(os.path.join(path, 'Data Sets', '2015_PCA.csv'))

# %%
reduced = reduced.drop(columns =['Unnamed: 0'])

# %%
reduced
# Out:
#           PCA1      PCA2      PCA3      PCA4      PCA5      PCA6      PCA7  \
# 0   -11.206884 -4.888417 -2.162944  0.796029  1.754975 -0.745449 -1.505893
# 1    -9.145452 -2.645571 -1.817134  0.844530  3.313819 -1.591326 -0.381237
# 2    -9.507543  0.937518 -0.735302  2.242264  1.666853  0.114031 -0.957630
# 3    -8.274451 -4.304123  0.760912  2.497907  0.833729  0.589352 -1.482760
# 4    -9.716356 -3.822423 -0.299320  1.745034  0.944961  1.809423 -1.119481
# ..         ...       ...       ...       ...       ...       ...       ...
# 360  -6.060710 -1.761092 -6.732471 -0.462927 -0.074291 -1.129686 -0.016666
# 361  -6.371380 -4.074005 -4.241877 -0.560280 -1.623983 -2.070603  0.834141
# 362  -8.147870 -3.158686 -4.156204  1.155326 -1.475966 -2.157730  1.077306
# 363  -8.567930 -2.119479 -4.378328 -0.407480 -1.668293 -3.379697  0.929506
# 364  -8.164196 -1.474803 -2.632136 -1.405969 -1.043229 -3.090165 -1.105476
#
#          PCA8      PCA9     PCA10
# ...

# %%
# Import Pleasant Weather Dataframe 
pleasant_weather = pd.read_csv(os.path.join(path, 'Data Sets', 'Dataset-Answers-Weather_Prediction_Pleasant_Weather.csv'))
pleasant_weather
# Out:
#            DATE  BASEL_pleasant_weather  BELGRADE_pleasant_weather  \
# 0      19600101                       0                          0
# 1      19600102                       0                          0
# 2      19600103                       0                          0
# 3      19600104                       0                          0
# 4      19600105                       0                          0
# ...         ...                     ...                        ...
# 22945  20221027                       0                          0
# 22946  20221028                       0                          0
# 22947  20221029                       0                          0
# 22948  20221030                       0                          0
# 22949  20221031                       0                          0
#
#        BUDAPEST_pleasant_weather  DEBILT_pleasant_weather  \
# 0                              0                        0
# ...

# %% [markdown]
# ## Dendrogram Single Method With Reduced Data

# %%
distance_single = linkage(reduced.loc[:,
['PCA1',
'PCA2']],method="single")
plt.figure(figsize=(18,6))
dendrogram(distance_single, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle("Dendrogram Single Method",fontsize=18)
plt.show()

# %% [markdown]
# ## Dendrogram Complete Method With Reduced Data

# %%
distance_complete = linkage(reduced.loc[:,
['PCA1',
'PCA2']],method="complete")
plt.figure(figsize=(18,6))
dendrogram(distance_complete, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle("Dendrogram Complete Method",fontsize=18)
plt.show()

# %% [markdown]
# ## Dendrogram Average Method With Reduced Data

# %%
distance_average = linkage(reduced.loc[:,
['PCA1',
'PCA2']],method="average")
plt.figure(figsize=(18,6))
dendrogram(distance_average, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle("Dendrogram Average Method",fontsize=18)
plt.show()

# %% [markdown]
# ## Dendrogram Ward Method with Reduced Data

# %%
distance_ward = linkage(reduced.loc[:,
['PCA1',
'PCA2']],method="ward")
plt.figure(figsize=(18,6))
dendrogram(distance_ward, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle("Dendrogram Ward Method",fontsize=18)
plt.show()

# %%
#Make a dataframe of the new components
df = pd.DataFrame(reduced, columns=['PCA1', 'PCA2'])

# %%
df
# Out:
#           PCA1      PCA2
# 0   -11.206884 -4.888417
# 1    -9.145452 -2.645571
# 2    -9.507543  0.937518
# 3    -8.274451 -4.304123
# 4    -9.716356 -3.822423
# ..         ...       ...
# 360  -6.060710 -1.761092
# 361  -6.371380 -4.074005
# 362  -8.147870 -3.158686
# 363  -8.567930 -2.119479
# 364  -8.164196 -1.474803
#
# [365 rows x 2 columns]

# %%
#Add the BASEL_pleasant_weather to the dataframe to show the relationship
basel_pleasant_weather = [pleasant_weather['BASEL_pleasant_weather']]
basel_pleasant_weather
# Out:
# [0        0
#  1        0
#  2        0
#  3        0
#  4        0
#          ..
#  22945    0
#  22946    0
#  22947    0
#  22948    0
#  22949    0
#  Name: BASEL_pleasant_weather, Length: 22950, dtype: int64]

# %%
df['BASEL_pleasant_weather']= pleasant_weather['BASEL_pleasant_weather']

# %%
df
# Out:
#           PCA1      PCA2  BASEL_pleasant_weather
# 0   -11.206884 -4.888417                       0
# 1    -9.145452 -2.645571                       0
# 2    -9.507543  0.937518                       0
# 3    -8.274451 -4.304123                       0
# 4    -9.716356 -3.822423                       0
# ..         ...       ...                     ...
# 360  -6.060710 -1.761092                       0
# 361  -6.371380 -4.074005                       0
# 362  -8.147870 -3.158686                       0
# 363  -8.567930 -2.119479                       0
# 364  -8.164196 -1.474803                       0
#
# [365 rows x 3 columns]

# %%
#PLot the two components
sns.set_theme()
g = sns.catplot(x="PCA1", y="PCA2", palette='Set1', hue="BASEL_pleasant_weather", data=df)
plt.xticks([0, 40, 80, 120, 149])
# Out:
# ([<matplotlib.axis.XTick at 0x2dc97bd7510>,
# ...
#  [Text(0, 0, '-11.646713670408538'),
#   Text(40, 0, '-8.729327018571366'),
#   Text(80, 0, '-6.518631019283313'),
#   Text(120, 0, '-4.474071672408259'),
#   Text(149, 0, '-2.97223073845993')])

# %%
#Add the MADRID_pleasant_weather to the dataframe to show the relationship
madrid_pleasant_weather = [pleasant_weather['MADRID_pleasant_weather']]
madrid_pleasant_weather
# Out:
# [0        0
#  1        0
#  2        0
#  3        0
#  4        0
#          ..
#  22945    0
#  22946    0
#  22947    0
#  22948    0
#  22949    0
#  Name: MADRID_pleasant_weather, Length: 22950, dtype: int64]

# %%
df['MADRID_pleasant_weather']= pleasant_weather['MADRID_pleasant_weather']

# %%
df
# Out:
#           PCA1      PCA2  BASEL_pleasant_weather  MADRID_pleasant_weather
# 0   -11.206884 -4.888417                       0                        0
# 1    -9.145452 -2.645571                       0                        0
# 2    -9.507543  0.937518                       0                        0
# 3    -8.274451 -4.304123                       0                        0
# 4    -9.716356 -3.822423                       0                        0
# ..         ...       ...                     ...                      ...
# 360  -6.060710 -1.761092                       0                        0
# 361  -6.371380 -4.074005                       0                        0
# 362  -8.147870 -3.158686                       0                        0
# 363  -8.567930 -2.119479                       0                        0
# 364  -8.164196 -1.474803                       0                        0
#
# [365 rows x 4 columns]

# %%
#PLot the two components
sns.set_theme()
g = sns.catplot(x="PCA1", y="PCA2", palette='Set1', hue="MADRID_pleasant_weather", data=df)
plt.xticks([0, 40, 80, 120, 149])
# Out:
# ([<matplotlib.axis.XTick at 0x2dc97d0c550>,
# ...
#  [Text(0, 0, '-11.646713670408538'),
#   Text(40, 0, '-8.729327018571366'),
#   Text(80, 0, '-6.518631019283313'),
#   Text(120, 0, '-4.474071672408259'),
#   Text(149, 0, '-2.97223073845993')])

# %%
#Add the STOCKHOLM_pleasant_weather to the dataframe to show the relationship
stockholm_pleasant_weather = [pleasant_weather['STOCKHOLM_pleasant_weather']]
stockholm_pleasant_weather
# Out:
# [0        0
#  1        0
#  2        0
#  3        0
#  4        0
#          ..
#  22945    0
#  22946    0
#  22947    0
#  22948    0
#  22949    0
#  Name: STOCKHOLM_pleasant_weather, Length: 22950, dtype: int64]

# %%
df['STOCKHOLM_pleasant_weather']= pleasant_weather['STOCKHOLM_pleasant_weather']

# %%
df
# Out:
#           PCA1      PCA2  BASEL_pleasant_weather  MADRID_pleasant_weather  \
# 0   -11.206884 -4.888417                       0                        0
# 1    -9.145452 -2.645571                       0                        0
# 2    -9.507543  0.937518                       0                        0
# 3    -8.274451 -4.304123                       0                        0
# 4    -9.716356 -3.822423                       0                        0
# ..         ...       ...                     ...                      ...
# 360  -6.060710 -1.761092                       0                        0
# 361  -6.371380 -4.074005                       0                        0
# 362  -8.147870 -3.158686                       0                        0
# 363  -8.567930 -2.119479                       0                        0
# 364  -8.164196 -1.474803                       0                        0
#
#      STOCKHOLM_pleasant_weather
# 0                             0
# ...

# %%
#PLot the two components
sns.set_theme()
g = sns.catplot(x="PCA1", y="PCA2", palette='Set1',hue="STOCKHOLM_pleasant_weather", data=df)
plt.xticks([0, 40, 80, 120, 149])
# Out:
# ([<matplotlib.axis.XTick at 0x2dc9a3f4f10>,
# ...
#  [Text(0, 0, '-11.646713670408538'),
#   Text(40, 0, '-8.729327018571366'),
#   Text(80, 0, '-6.518631019283313'),
#   Text(120, 0, '-4.474071672408259'),
#   Text(149, 0, '-2.97223073845993')])

# %%
# Choose a threshold value to cut the dendrogram
threshold = 70

# %%
# Create clusters
clusters = fcluster(distance_ward, threshold, criterion='distance')

# %%
df['Cluster'] = clusters
df
# Out:
#           PCA1      PCA2  BASEL_pleasant_weather  MADRID_pleasant_weather  \
# 0   -11.206884 -4.888417                       0                        0
# 1    -9.145452 -2.645571                       0                        0
# 2    -9.507543  0.937518                       0                        0
# 3    -8.274451 -4.304123                       0                        0
# 4    -9.716356 -3.822423                       0                        0
# ..         ...       ...                     ...                      ...
# 360  -6.060710 -1.761092                       0                        0
# 361  -6.371380 -4.074005                       0                        0
# 362  -8.147870 -3.158686                       0                        0
# 363  -8.567930 -2.119479                       0                        0
# 364  -8.164196 -1.474803                       0                        0
#
#      STOCKHOLM_pleasant_weather  Cluster
# ...

# %%
#PLot the two components
sns.set_theme()
g = sns.catplot(x="PCA1", y="PCA2", palette='Set1', hue="Cluster", data=df)
plt.xticks([0, 40, 80, 120, 149])
# Out:
# ([<matplotlib.axis.XTick at 0x2dc9b0c6f50>,
# ...
#  [Text(0, 0, '-11.646713670408538'),
#   Text(40, 0, '-8.729327018571366'),
#   Text(80, 0, '-6.518631019283313'),
#   Text(120, 0, '-4.474071672408259'),
#   Text(149, 0, '-2.97223073845993')])

# %% [markdown]
# #### There are 2 definite clusters in this plot which indicates that the labels match the clusters in terms of pleasant vs unpleasant weather. However, this is not 100% perfect as there are data points that may be inaccurate with clustering.
